# %%
import fastf1
import pandas as pd

# %%
session = fastf1.get_session(2023, 'Monza', 'Q')
session.load(telemetry=True, laps=False, weather=False)
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Qualifying [v3.3.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# ...

# %%
session
# Out:
# 2023 Season Round 14: Italian Grand Prix - Qualifying

# %%
df = pd.DataFrame(session.car_data, orient = "records")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.DataFrame(session.car_data, orient = "records")
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'orient'

# %%
lw = session.car_data["44"]

# %%
lw
# Out:
#                          Date  RPM  Speed  nGear  Throttle  Brake  DRS Source  \
# 0     2019-09-07 12:45:02.230    0      0      0         0  False    0    car
# 1     2019-09-07 12:45:02.470    0      0      0         0  False    0    car
# 2     2019-09-07 12:45:02.710    0      0      0         0  False    0    car
# 3     2019-09-07 12:45:02.990    0      0      0         0  False    0    car
# 4     2019-09-07 12:45:03.230    0      0      0         0  False    0    car
# ...                       ...  ...    ...    ...       ...    ...  ...    ...
# 23138 2019-09-07 14:18:27.837    0      0      0       104   True    8    car
# 23139 2019-09-07 14:18:28.076    0      0      0       104   True    8    car
# 23140 2019-09-07 14:18:28.316    0      0      0       104   True    8    car
# 23141 2019-09-07 14:18:28.517    0      0      0       104   True    8    car
# 23142 2019-09-07 14:18:28.757    0      0      0       104   True    8    car
#
# ...

# %%
lw_pos= session.pos_data["44"]

# %%
lw_pos.iloc[0:4].Date
# Out:
# 0   2019-09-07 12:45:02.299
# 1   2019-09-07 12:45:02.599
# 2   2019-09-07 12:45:02.899
# 3   2019-09-07 12:45:03.199
# Name: Date, dtype: datetime64[ns]

# %%
lw.iloc[0:4].Date
# Out:
# 0   2019-09-07 12:45:02.230
# 1   2019-09-07 12:45:02.470
# 2   2019-09-07 12:45:02.710
# 3   2019-09-07 12:45:02.990
# Name: Date, dtype: datetime64[ns]

# %%
lw.iloc[6000]
# Out:
# Date           2019-09-07 13:09:24.206000
# RPM                                 12366
# Speed                                 264
# nGear                                   6
# Throttle                               99
# Brake                               False
# DRS                                     8
# Source                                car
# Time               0 days 00:24:23.113000
# SessionTime        0 days 00:24:23.113000
# Name: 6000, dtype: object

# %%
lw_moving = lw_pos[lw_pos.X != -8323]

# %%
from matplotlib import pyplot as plt

# %%
lw_moving
# Out:
#                          Date   Status    X      Y     Z Source  \
# 4519  2019-09-07 13:07:24.621  OnTrack -746   6239     0    pos
# 4520  2019-09-07 13:07:24.921  OnTrack -723   6498     0    pos
# 4521  2019-09-07 13:07:25.221  OnTrack -711   6638     0    pos
# 4522  2019-09-07 13:07:25.521  OnTrack -691   6867     0    pos
# 4523  2019-09-07 13:07:25.821  OnTrack -671   7096     0    pos
# ...                       ...      ...  ...    ...   ...    ...
# 18361 2019-09-07 14:15:56.590  OnTrack -414  10476  1872    pos
# 18362 2019-09-07 14:15:56.890  OnTrack -398  10675  1872    pos
# 18363 2019-09-07 14:15:57.190  OnTrack -383  10864  1872    pos
# 18364 2019-09-07 14:15:57.491  OnTrack -366  11084  1872    pos
# 18365 2019-09-07 14:15:57.791  OnTrack -350  11293  1872    pos
#
#                         Time            SessionTime
# 4519  0 days 00:22:23.528000 0 days 00:22:23.528000
# 4520  0 days 00:22:23.828000 0 days 00:22:23.828000
# ...

# %%
idk= session.pos_data["16"]

# %%
idk_moving = idk[idk["X"] != -8323]

# %%
import matplotlib.pyplot as plt

# Plotting the first scatter plot with blue color
plt.scatter(idk_moving["X"][0:50], idk_moving["Y"][0:50], color='blue', label='idk_moving')

# Plotting the second scatter plot with red color
plt.scatter(lw_moving["X"][0:1000], lw_moving["Y"][0:1000], color='red', label='lw_moving')

# Adding legend
plt.legend()

# Show plot
plt.show()

# %%
18779  + 23143
# Out:
# 41922

# %%
merged = pd.merge(lw_pos, lw, on = ["Date", "Time","SessionTime"], how = "outer")

# %%
merged
# Out:
#                          Date   Status       X       Y    Z Source_x  \
# 0     2019-09-07 12:45:02.299  OnTrack -8323.0 -6449.0  0.0      pos
# 1     2019-09-07 12:45:02.599  OnTrack -8323.0 -6449.0  0.0      pos
# 2     2019-09-07 12:45:02.899  OnTrack -8323.0 -6449.0  0.0      pos
# 3     2019-09-07 12:45:03.199  OnTrack -8323.0 -6449.0  0.0      pos
# 4     2019-09-07 12:45:03.499  OnTrack -8323.0 -6449.0  0.0      pos
# ...                       ...      ...     ...     ...  ...      ...
# 41870 2019-09-07 14:18:27.837      NaN     NaN     NaN  NaN      NaN
# 41871 2019-09-07 14:18:28.076      NaN     NaN     NaN  NaN      NaN
# 41872 2019-09-07 14:18:28.316      NaN     NaN     NaN  NaN      NaN
# 41873 2019-09-07 14:18:28.517      NaN     NaN     NaN  NaN      NaN
# 41874 2019-09-07 14:18:28.757      NaN     NaN     NaN  NaN      NaN
#
#                         Time            SessionTime  RPM  Speed  nGear  \
# ...
